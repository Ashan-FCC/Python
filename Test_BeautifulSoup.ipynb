# %%
from bs4 import BeautifulSoup as bs

# %%
path = "D:/t2pdev/data/api/t2p_checkout/payment_form.php"
soup = bs(open(path,encoding="utf-8"),"html.parser")

# %%
print(soup.prettify())
# Out:
# <?php
# ini_set('zlib.output_compression_level', 5);
# ob_start("ob_gzhandler");
# error_reporting(E_ALL);
# ini_set('display_errors', '1');
#
# header("content-type:text/plain;charset=utf-8");
# include_once($_SERVER['DOCUMENT_ROOT']."/runtime.inc.php");
# import('util.IbahtRSA');
# import('util.Util');
# import('api.db');
# loadconfig('t2pconfig.php');
# loadconfig('config_db.php');
# loadconfig('config_sms.php');
# import('util.sms');
# import('bill.BPayment');
# import('bill.BPaymentUtil');
# import('bill.BMerchantMan');
# import('bill.BPaySabuy');
# import('cs_paysbuy.Counter_service');
#
# $payment_form = "Result from payment_form.php: ";
# $sep = '';
# $data = '';
# $log = '';
# $merchantID = '';
# $password = '';
# $frontUrl = '';
# $baseURL = '';
#
# $modeIframe = true;
# //@Util::LogFile("Pay-Form", print_r($_POST,true)."\r\n".print_r($_GET,true));
# $req = @$_POST['reqq'];
# $client = isset($_POST['CLI'])?$_POST['CLI']:"";
#
# ...
