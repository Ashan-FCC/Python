# %%
import sys;
from bs4 import BeautifulSoup

# %%
f = open('D:/Ashan/Desktop/forsale.txt','r', encoding="utf8");
filecontents = f.read();
soup = BeautifulSoup(filecontents, 'html.parser')
print(soup.prettify())
# Out:
# <div class="_5pcb" data-referrer="group_forsale_mall_forsale_available_188966707797259" id="group_forsale_mall_forsale_available_188966707797259" style="min-height: 100px;">
#  <h2 class="accessible_elem" id="newsFeedHeading">
#   News Feed
#  </h2>
# ...
